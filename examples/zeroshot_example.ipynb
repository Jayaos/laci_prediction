# %% [markdown]
# ## Environment setup

# %%
# !git clone https://github.com/Jayaos/LacI_prediction

# %%
# %cd /content/LacI_prediction/
# !pwd

# %% [markdown]
# ## Example

# %%
from src.esm_zeroshot.run import *
from src.constants import *

# %%
nfold_evaluate_zeroshot_single_mutation("C:/Users/jayao/Desktop/python_projects/allostery_ML/data/laci/binary_full_sequence_data/",
                              "binary_full_sequence_data", "esm2_t6_8M_UR50D", LACI_WT, 5, "binary", False, 0)
