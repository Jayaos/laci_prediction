# %% [markdown]
# ## Environment setup

# %%
# !pip install fair-esm==2.0.0
# !pip install torch torchmetrics==1.2.1

# %%
# !git clone https://github.com/Jayaos/LacI_prediction

# %%
# %cd /content/LacI_prediction/
# !pwd

# %%
from src.esm_zeroshot.run import *
from src.constants import *

# %% [markdown]
# ## Zero-shot prediction of wild-type LacI single mutation

# %%
nfold_evaluate_zeroshot_single_mutation("/content/LacI_prediction/data/laci/binary_full_sequence_data/",
                                        "binary_full_sequence_data", "esm2_t6_8M_UR50D", LACI_WT, 5, "binary", False, "cpu")

# %% [markdown]
# nfold_evaluate_zeroshot_single_mutation("/content/LacI_prediction/data/laci/binary_full_sequence_data/",
#                                         "binary_full_sequence_data", "esm2_t6_8M_UR50D", LACI_WT, 5, "score", False, "cpu")

# %% [markdown]
# ## Zero-shot prediction of IA5 LacI single mutation

# %%
nfold_evaluate_zeroshot_single_mutation("/content/LacI_prediction/data/laci/binary_full_sequence_data/",
                                        "binary_full_sequence_data", "esm2_t6_8M_UR50D", IA5_WT, 5, "binary", False, "cpu")

# %%
nfold_evaluate_zeroshot_single_mutation("/content/LacI_prediction/data/laci/binary_full_sequence_data/",
                                        "binary_full_sequence_data", "esm2_t6_8M_UR50D", IA5_WT, 5, "score", False, "cpu")

# %% [markdown]
# ## Zero-shot prediction of IA9 LacI single mutation

# %%
nfold_evaluate_zeroshot_single_mutation("/content/LacI_prediction/data/laci/binary_full_sequence_data/",
                                        "binary_full_sequence_data", "esm2_t6_8M_UR50D", IA9_WT, 5, "binary", False, "cpu")

# %%
nfold_evaluate_zeroshot_single_mutation("/content/LacI_prediction/data/laci/binary_full_sequence_data/",
                                        "binary_full_sequence_data", "esm2_t6_8M_UR50D", IA9_WT, 5, "score", False, "cpu")
